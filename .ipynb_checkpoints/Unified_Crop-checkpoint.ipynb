# %%
# LOAD DATASETS
import pandas as pd
crop_df = pd.read_csv("Dataset_X.csv")
soil_df = pd.read_csv("Dataset_Y.csv")

print(crop_df.shape, soil_df.shape)
# Out:
# (236496, 9) (695, 10)

# %%
# Normalize text (safety)
for col in ["state", "district", "crop"]:
    crop_df[col] = crop_df[col].str.strip().str.lower()
    soil_df[col] = soil_df[col].str.strip().str.lower()

# %%
crop_df
# Out:
#                               state  district  year  season       crop  \
# 0       andaman and nicobar islands  nicobars  2000  kharif   arecanut
# 1       andaman and nicobar islands  nicobars  2000  kharif       rice
# 2       andaman and nicobar islands  nicobars  2000  annual     banana
# 3       andaman and nicobar islands  nicobars  2000  annual     cashew
# 4       andaman and nicobar islands  nicobars  2000  annual    coconut
# ...                             ...       ...   ...     ...        ...
# 236491                  west bengal   purulia  2014  summer       rice
# 236492                  west bengal   purulia  2014  summer    sesamum
# 236493                  west bengal   purulia  2014  annual  sugarcane
# 236494                  west bengal   purulia  2014    rabi       rice
# 236495                  west bengal   purulia  2014    rabi    sesamum
#
#             area   production  yield_log  risk
# 0         1254.0    2000.0000   0.953547     1
# ...

# %%
soil_df
# Out:
#                  state                                        district  \
# 0          maharashtra                ahilya nagar, maharashtra, india
# 1          maharashtra                       akola, maharashtra, india
# 2          maharashtra                    amravati, maharashtra, india
# 3          maharashtra  chhatrapati sambhaji nagar, maharashtra, india
# 4          maharashtra                 beed, maharashtra 431122, india
# ..                 ...                                             ...
# 690  jammu and kashmir                                 udhampur 182101
# 691             ladakh                                   kargil 194103
# 692             ladakh                                             leh
# 693         puducherry                     karaikal, puducherry, india
# 694         puducherry                               puducherry, india
#
#           crop   latitude  longitude       n       p       k      ph  \
# ...

# %%
# Check matching keys
common_districts = set(crop_df["state"]) & set(soil_df["state"])
common_crops = set(crop_df["crop"]) & set(soil_df["crop"])

print("Common states:", len(common_districts))
print("Common crops:", len(common_crops))
# Out:
# Common states: 31
# Common crops: 29

# %%
soil_state = soil_df.groupby("state").agg({
    "n": "mean",
    "p": "mean",
    "k": "mean",
    "ph": "mean"
}).reset_index()

soil_state["soil_fertility"] = (
    soil_state["n"] + soil_state["p"] + soil_state["k"]
) / 3

soil_state
# Out:
#                           state         n         p         k        ph  \
# 0   andaman and nicobar islands  1.138133  1.087967  1.176000  6.805733
# 1                andhra pradesh  1.285024  2.329892  2.429084  7.116136
# 2             arunachal pradesh  2.049227  2.168319  1.976504  5.970973
# 3                         assam  2.411303  2.491528  1.663491  6.236522
# 4                         bihar  1.410669  2.756422  2.166022  6.928597
# 5                  chhattisgarh  1.261057  1.869829  2.424039  6.795114
# 6                           goa  2.017500  1.679500  1.959850  5.671950
# 7                       gujarat  1.215297  2.562815  2.542588  7.025764
# 8                       haryana  0.000000  2.481260  2.045090  7.049800
# 9              himachal pradesh  1.408350  2.236892  2.301575  6.986542
# 10            jammu and kashmir  2.015070  2.361910  2.151255  6.989545
# 11                    jharkhand  1.564854  2.149246  1.957067  6.223233
# ...

# %%
merged_df = pd.merge(
    crop_df,
    soil_state,
    on="state",
    how="left",
    validate="many_to_one",
    indicator=True
)
merged_df=merged_df.dropna()
merged_df = merged_df.drop(columns=["_merge"])
print(merged_df.columns)
merged_df
# Out:
# Index(['state', 'district', 'year', 'season', 'crop', 'area', 'production',
#        'yield_log', 'risk', 'n', 'p', 'k', 'ph', 'soil_fertility'],
#       dtype='str')
#                               state  district  year  season       crop  \
# 0       andaman and nicobar islands  nicobars  2000  kharif   arecanut
# 1       andaman and nicobar islands  nicobars  2000  kharif       rice
# 2       andaman and nicobar islands  nicobars  2000  annual     banana
# 3       andaman and nicobar islands  nicobars  2000  annual     cashew
# 4       andaman and nicobar islands  nicobars  2000  annual    coconut
# ...                             ...       ...   ...     ...        ...
# 236491                  west bengal   purulia  2014  summer       rice
# 236492                  west bengal   purulia  2014  summer    sesamum
# 236493                  west bengal   purulia  2014  annual  sugarcane
# 236494                  west bengal   purulia  2014    rabi       rice
# ...

# %%
df = merged_df[[
    "state",
    "district",
    "year",
    "season",
    "crop",
    "area",
    "production",
    "yield_log",
    "n",
    "p",
    "k",
    "ph",
    "soil_fertility",
    "risk"
]]
df
# Out:
#                               state  district  year  season       crop  \
# 0       andaman and nicobar islands  nicobars  2000  kharif   arecanut
# 1       andaman and nicobar islands  nicobars  2000  kharif       rice
# 2       andaman and nicobar islands  nicobars  2000  annual     banana
# 3       andaman and nicobar islands  nicobars  2000  annual     cashew
# 4       andaman and nicobar islands  nicobars  2000  annual    coconut
# ...                             ...       ...   ...     ...        ...
# 236491                  west bengal   purulia  2014  summer       rice
# 236492                  west bengal   purulia  2014  summer    sesamum
# 236493                  west bengal   purulia  2014  annual  sugarcane
# 236494                  west bengal   purulia  2014    rabi       rice
# 236495                  west bengal   purulia  2014    rabi    sesamum
#
#             area   production  yield_log         n         p        k  \
# ...

# %%
df.to_csv("Dataset_Z.csv", index=False)

print("Unified dataset ready")
# Out:
# Unified dataset ready
